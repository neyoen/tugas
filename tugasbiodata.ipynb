# %%
nik = "******************"
nama = "Arion Camara"
tempat = "Pontianak"
tgllahir = "08-08-2002"
gender = "Laki-laki"
alamat = """Jln.Pangeran Permai Gg. Pati 1
      RT/RW      :  01/29
      Kel/Desa   :  Siantan Hulu
      Kecamatan  :  Pontianak Utara
"""
agama = "Katolik"
status = "Belum Kawin"
pekerjaan = "Pelajar/Mahasiswa"
kewarganegaraan = "WNI"
berlakuhingga = "Seumur Hidup"

print ("""       PROVINSI KALIMANTAN BARAT
            PONTIANAK UTARA
            """)

print ("NIK              : ", nik)
print ("Nama             : ", nama)
print ("Tempat/Tgl Lahir : ", tempat, tgllahir)
print ("Jenis Kelamin    : ", gender, "        Gol. Darah : -")
print ("Alamat           : ", alamat)
print ("Agama            : ", agama)
print ("Status           : ", status)
print ("Pekerjaan        : ", pekerjaan)
print ("Kewarganegaraan  : ", kewarganegaraan)
print ("Berlaku Hingga   : ", berlakuhingga)
# Out:
#        PROVINSI KALIMANTAN BARAT
#             PONTIANAK UTARA
#
# NIK              :  ******************
# Nama             :  Arion Camara
# Tempat/Tgl Lahir :  Pontianak 08-08-2002
# Jenis Kelamin    :  Laki-laki         Gol. Darah : -
# Alamat           :  Jln.Pangeran Permai Gg. Pati 1
#       RT/RW      :  01/29
#       Kel/Desa   :  Siantan Hulu
#       Kecamatan  :  Pontianak Utara
#
# Agama            :  Katolik
# Status           :  Belum Kawin
# Pekerjaan        :  Pelajar/Mahasiswa
# Kewarganegaraan  :  WNI
# Berlaku Hingga   :  Seumur Hidup

# %%
nama = "Arion Camara"
ttl = "Pontianak, 08-08-2002"
goldargender = "O - Pria"
alamat = """GG PATI 1 NO C/10
    SIANTAN HULU
    PONTIANAK UTARA"""
pekerjaan = "PELAJAR"
provinsi = "KALBAR"

print ("""    INDONESIA
    SURAT IJIN MENGEMUDI                  DRIVING LICENSE""")
print ("1. ", nama)
print ("2. ", ttl)
print ("3. ", goldargender)
print ("4. ", alamat)
print ("5. ", pekerjaan)
print ("6. ", provinsi)

print ("""
                                          21-07-2023""")
# Out:
#     INDONESIA
#     SURAT IJIN MENGEMUDI                  DRIVING LICENSE
# 1.  Arion Camara
# 2.  Pontianak, 08-08-2002
# 3.  O - Pria
# 4.  GG PATI 1 NO C/10
#     SIANTAN HULU
#     PONTIANAK UTARA
# 5.  PELAJAR
# 6.  KALBAR
#
#                                           21-07-2023

# %%
nama = "Arion Camara"
umur = "19 Tahun"
ttl = "Pontianak/08-08-2002"
agama = "Katolik"
bangsa = "WNI"
alamat = "Jln. Pangeran Permai Gg. Pati 1"
sd = "SD Bruder Kanisius"
smp = "SMP Santo Fransiskus Asisi"
sma = "SMA Santo Fransiskus Asisi"

print("""                   DAFTAR RIWAYAT HIDUP
""")
print("Nama              : ", nama)
print("Umur              : ", umur)
print("Tempat/Tgl. Lahir : ", ttl)
print("Agama             : ", agama)
print("Bangsa : ", bangsa)
print("""Tempat Tinggal 
Sekarang          : """, alamat)

print("""Menerangkan dengan sesungguhnya :
""")
print("""                        PENDIDIKAN
""")
print("1. Tamatan......................................berijazah/tidak*")
print("2. Tamatan......................................berijazah/tidak*")
print("3. Tamatan......................................berijazah/tidak*")
print("""4. Pernah memasuki Fakultas/Akademi..............
   sampai tingkat Persiapan/Sarjana Muda (BA)* Doktoral/Sarjana*""")
print("""
                      PENGALAMAN KERJA
                      """)
print("1. Dari Tahun..................s/d tahun........................")
print("2. Dari Tahun..................s/d tahun........................")
print("3. Dari Tahun..................s/d tahun........................")
print("4. Keterangan lain-lain.........................................")
print("Demikianlah daftar riwayat hidup ini saya buat dengan sebenarnya")
print("""                                                  ..........20..""")
print("""                                          Saya yang bersangkutan""")
print("""

*) Coret yang tidak perlu                (.....................)""")
# Out:
#                    DAFTAR RIWAYAT HIDUP
#
# Nama              :  Arion Camara
# Umur              :  19 Tahun
# Tempat/Tgl. Lahir :  Pontianak/08-08-2002
# Agama             :  Katolik
# Bangsa :  WNI
# Tempat Tinggal
# Sekarang          :  Jln. Pangeran Permai Gg. Pati 1
# Menerangkan dengan sesungguhnya :
#
#                         PENDIDIKAN
#
# 1. Tamatan......................................berijazah/tidak*
# 2. Tamatan......................................berijazah/tidak*
# 3. Tamatan......................................berijazah/tidak*
# 4. Pernah memasuki Fakultas/Akademi..............
#    sampai tingkat Persiapan/Sarjana Muda (BA)* Doktoral/Sarjana*
#
#                       PENGALAMAN KERJA
#
# 1. Dari Tahun..................s/d tahun........................
# 2. Dari Tahun..................s/d tahun........................
# 3. Dari Tahun..................s/d tahun........................
# 4. Keterangan lain-lain.........................................
# ...
